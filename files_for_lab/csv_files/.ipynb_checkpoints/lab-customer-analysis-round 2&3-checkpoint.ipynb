# %% [markdown]
# **LAB - CUSTOMER ANALYSIS ROUND 2-3**

# %% [markdown]
# **LAB 2**

# %%
# !pip3 install pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Dealing with the data**

# %%
#Read the file as a dataframe

file1 = pd.read_csv('marketing_customer_analysis.csv')
file1 = file1.drop(['Unnamed: 0'],axis=1)
file1
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %% [markdown]
# **Show the dataframe shape**

# %%
file1.shape
# Out:
# (9134, 27)

# %%
#show all the columns

pd.set_option('display.max_columns', None)

# %% [markdown]
# **Standardize header names**

# %%
file1 = file1.rename(columns={'EmploymentStatus':'Employment Status'})

# %%
file1.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   Effective To Date Employment Status Gender  Income Location Code  \
# 0           2/18/11          Employed      M   48029      Suburban
# 1           1/18/11        Unemployed      F       0      Suburban
# 2           2/10/11          Employed      M   22139      Suburban
# 3           1/11/11          Employed      M   49078      Suburban
# 4           1/17/11     Medical Leave      F   23675      Suburban
#
#   Marital Status  Monthly Premium Auto  Months Since Last Claim  \
# ...

# %% [markdown]
# **Which columns are numerical?**

# %%
file1._get_numeric_data()
# Out:
#        Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        Months Since Last Claim  Months Since Policy Inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %% [markdown]
# **Which columns are categorical?**

# %%
file1.select_dtypes('object')
# Out:
#       Customer       State Response  Coverage Education Effective To Date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       Employment Status Gender Location Code Marital Status     Policy Type  \
# ...

# %% [markdown]
# **Check and deal with NaN values**

# %%
file1.isna().sum()
# Out:
# Customer                            0
# State                             631
# Customer Lifetime Value             0
# Response                          631
# Coverage                            0
# Education                           0
# Effective To Date                   0
# Employment Status                   0
# Gender                              0
# Income                              0
# Location Code                       0
# Marital Status                      0
# Monthly Premium Auto                0
# Months Since Last Claim           633
# Months Since Policy Inception       0
# Number of Open Complaints         633
# Number of Policies                  0
# Policy Type                         0
# Policy                              0
# Renew Offer Type                    0
# Sales Channel                       0
# Total Claim Amount                  0
# Vehicle Class                     622
# Vehicle Size                      622
# Vehicle Type                     5482
# ...

# %%
round(file1.isna().sum()/len(file1),4)*100
# Out:
# Customer                          0.00
# State                             5.78
# Customer Lifetime Value           0.00
# Response                          5.78
# Coverage                          0.00
# Education                         0.00
# Effective To Date                 0.00
# Employment Status                 0.00
# Gender                            0.00
# Income                            0.00
# Location Code                     0.00
# Marital Status                    0.00
# Monthly Premium Auto              0.00
# Months Since Last Claim           5.80
# Months Since Policy Inception     0.00
# Number of Open Complaints         5.80
# Number of Policies                0.00
# Policy Type                       0.00
# Policy                            0.00
# Renew Offer Type                  0.00
# Sales Channel                     0.00
# Total Claim Amount                0.00
# Vehicle Class                     5.70
# Vehicle Size                      5.70
# ...

# %%
nulls_df = pd.DataFrame(round(file1.isna().sum()/len(file1),4)*100)
nulls_df
nulls_df = nulls_df.reset_index()
nulls_df
nulls_df.columns = ['header_name', 'percent_nulls']
nulls_df
# Out:
#                       header_name  percent_nulls
# 0                        Customer           0.00
# 1                           State           5.78
# 2         Customer Lifetime Value           0.00
# 3                        Response           5.78
# 4                        Coverage           0.00
# 5                       Education           0.00
# 6               Effective To Date           0.00
# 7               Employment Status           0.00
# 8                          Gender           0.00
# 9                          Income           0.00
# 10                  Location Code           0.00
# 11                 Marital Status           0.00
# 12           Monthly Premium Auto           0.00
# 13        Months Since Last Claim           5.80
# 14  Months Since Policy Inception           0.00
# 15      Number of Open Complaints           5.80
# 16             Number of Policies           0.00
# 17                    Policy Type           0.00
# ...

# %%
# Delete NaN

file1 = file1.dropna(subset=['State', 'Response', 'Number of Open Complaints', 'Months Since Last Claim', 'Vehicle Class', 'Vehicle Size'])
file1
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   Education Effective To Date Employment Status Gender  \
# ...

# %%
nulls_df = pd.DataFrame(round(file1.isna().sum()/len(file1),4)*100)
nulls_df
nulls_df = nulls_df.reset_index()
nulls_df
nulls_df.columns = ['header_name', 'percent_nulls']
nulls_df
# Out:
#                       header_name  percent_nulls
# 0                        Customer           0.00
# 1                           State           0.00
# 2         Customer Lifetime Value           0.00
# 3                        Response           0.00
# 4                        Coverage           0.00
# 5                       Education           0.00
# 6               Effective To Date           0.00
# 7               Employment Status           0.00
# 8                          Gender           0.00
# 9                          Income           0.00
# 10                  Location Code           0.00
# 11                 Marital Status           0.00
# 12           Monthly Premium Auto           0.00
# 13        Months Since Last Claim           0.00
# 14  Months Since Policy Inception           0.00
# 15      Number of Open Complaints           0.00
# 16             Number of Policies           0.00
# 17                    Policy Type           0.00
# ...

# %%
#rename NaN Values in the column Vehicle Type 

file1['Vehicle Type'] = file1['Vehicle Type'].fillna("Unknown")
file1
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   Education Effective To Date Employment Status Gender  \
# ...

# %% [markdown]
# **Data time format Extract the months from the dataset and store in a separate column**

# %%
file1['Month'] = pd.DatetimeIndex(file1['Effective To Date']).month
file1
file1['Month'] = pd.to_datetime(file1['Effective To Date'], format='%m/%d/%y').dt.strftime('%B')
file1
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   Education Effective To Date Employment Status Gender  \
# ...

# %%
#filtering 

file1_filtered = file1[file1['Month'].isin(['January', 'February', 'March'])]
file1_filtered
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   Education Effective To Date Employment Status Gender  \
# ...

# %%
#she created an excel #data.to_csv('cleaned_filled.csv', index=False)

# %%
# #data = pd.read_csv('marketing_customer_analysis.csv')


# def clean_data(df):
#     df.columns=[e.lower().replace(' ','_') for e in df.columns]
#     df=df.drop(columns=['unnamend:0'])
#     df['Vehicle_type']=df['Vehicle'].fillna('M')
#     df=df.dropna()
#     df['effective_to_date']=pd.to_datetime(df['effective_to_date'], errors='coerce')
#     df['month'] = df['effective_to_date'].dt.month
#     return df
    
    
# data1=clean_data(data)
# data1

# %%
#she add the new data clean #data2 = pd.read.csv('cleaned_filled.csv')

# %% [markdown]
# **LAB 3**

# %% [markdown]
# **Show dataframe info**

# %%
file1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9134 entries, 0 to 10908
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   Employment Status              9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
# ...

# %% [markdown]
# **DescribeDataFrame**

# %%
file1.describe()

file1.describe().T
# Out:
#                                 count          mean           std  \
# Customer Lifetime Value        9134.0   8004.940475   6870.967608
# Income                         9134.0  37657.380009  30379.904734
# Monthly Premium Auto           9134.0     93.219291     34.407967
# Months Since Last Claim        9134.0     15.097000     10.073257
# Months Since Policy Inception  9134.0     48.064594     27.905991
# Number of Open Complaints      9134.0      0.384388      0.910384
# Number of Policies             9134.0      2.966170      2.390182
# Total Claim Amount             9134.0    434.088794    290.500092
#
#                                        min          25%           50%  \
# Customer Lifetime Value        1898.007675  3994.251794   5780.182197
# Income                            0.000000     0.000000  33889.500000
# Monthly Premium Auto             61.000000    68.000000     83.000000
# Months Since Last Claim           0.000000     6.000000     14.000000
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Show a plot of the total number of responses**

# %%
file1['Response'].value_counts()
# Out:
# No     7826
# Yes    1308
# Name: Response, dtype: int64

# %%
sns.countplot(data = file1, x = 'Response', order = ['Yes', 'No'])
# Out:
# <Axes: xlabel='Response', ylabel='count'>

# %% [markdown]
# **Show a plot of the response rate by the sales channel.**

# %%
file1 ['Response Rate'] = np.where(file1['Response'] == 'Yes', 1, 0)
file1
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 6      IW72280  California              5035.035257       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   Education Effective To Date Employment Status Gender  \
# ...

# %%
sns.barplot(x = 'Sales Channel', y = 'Response Rate', data = file1 )
# Out:
# <Axes: xlabel='Sales Channel', ylabel='Response Rate'>

# %% [markdown]
# **Show a plot of the response rate by the total claim amount.**

# %%
sns.displot(file1, x = 'Total Claim Amount', hue = 'Response Rate', bins=20)

# %% [markdown]
# **Show a plot of the response rate by income**

# %%
sns.displot(file1, x = 'Income', hue = 'Response Rate', bins=20)

# %%
file1.to_csv("cleaned_marketing_customer.csv", index = False)

# %% [markdown]
# **LAB 4**

# %% [markdown]
# Check the data types of the columns

# %%
file1.dtypes
# Out:
# Customer                          object
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# Employment Status                 object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim          float64
# Months Since Policy Inception      int64
# Number of Open Complaints        float64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# Vehicle Class                     object
# ...

# %% [markdown]
# Get the numeric data into dataframe

# %%
numericals = file1.select_dtypes(include=[np.number])
numericals
# Out:
#        Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 6                  5035.035257   37405                    63
# ...                        ...     ...                   ...
# 10903              2771.663013   59855                    74
# 10904             19228.463620       0                   187
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
#
#        Months Since Last Claim  Months Since Policy Inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %%
categoricals = file1.select_dtypes(include=[object])
categoricals
# Out:
#       Customer       State Response  Coverage             Education  \
# 0      DK49336     Arizona       No     Basic               College
# 1      KX64629  California       No     Basic               College
# 2      LZ68649  Washington       No     Basic              Bachelor
# 3      XL78013      Oregon      Yes  Extended               College
# 6      IW72280  California       No     Basic                Doctor
# ...        ...         ...      ...       ...                   ...
# 10903  SU71163     Arizona       No     Basic               College
# 10904  QI63521      Nevada       No     Basic  High School or Below
# 10906  KX53892      Oregon       No     Basic               College
# 10907  TL39050     Arizona       No  Extended              Bachelor
# 10908  WA60547  California       No   Premium               College
#
#       Effective To Date Employment Status Gender Location Code Marital Status  \
# ...

# %% [markdown]
# Check the normality of the numerical variables visually

# %% [markdown]
# Seaborn library to construct distribution plots for the numerical variables

# %%
sns.displot(numerical, x="Monthly Premium Auto", bins=20)

# %%
sns.displot(numerical, x="Income", shrink=.8)

# %%
numericals_columns = list(numericals.head(0))

for i in numericals_columns:
    sns.displot(file1[i])

plt.show()

# %% [markdown]
# **Use Matplotlib to construct histograms**

# %%
import matplotlib.pyplot as plt

# %%
numericals_columns = list(numericals.head(0))

for i in numericals_columns:
    plt.hist(file1[i])
    plt.title(i)
    plt.show()

# %% [markdown]
# **Do the distributions for different numerical variables look like a normal distribution**

# %% [markdown]
# Distributions don´t look normal

# %% [markdown]
# **For the numerical variables, check the multicollinearity between the features. Please note that we will use the column total_claim_amount later as the target variable**

# %%
correlations_matrix = file1.corr()
sns.heatmap(correlations_matrix, annot=True)
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_4596\3630683468.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlations_matrix = file1.corr()

# %% [markdown]
# **Drop one of the two features that show a high correlation between them (greater than 0.9). Write code for both the correlation matrix and for seaborn heatmap. If there is no pair of features that have a high correlation, then do not drop any features**

# %%
correlations_matrix
# Out:
#                                Customer Lifetime Value    Income  \
# Customer Lifetime Value                       1.000000  0.024366
# Income                                        0.024366  1.000000
# Monthly Premium Auto                          0.396262 -0.016665
# Months Since Last Claim                       0.011517 -0.026715
# Months Since Policy Inception                 0.009418 -0.000875
# Number of Open Complaints                    -0.036343  0.006408
# Number of Policies                            0.021955 -0.008656
# Total Claim Amount                            0.226451 -0.355254
# Response Rate                                -0.008930  0.011932
#
#                                Monthly Premium Auto  Months Since Last Claim  \
# Customer Lifetime Value                    0.396262                 0.011517
# Income                                    -0.016665                -0.026715
# Monthly Premium Auto                       1.000000                 0.005026
# ...

# %% [markdown]
# We could't find any high correlation between the features in the matrix
